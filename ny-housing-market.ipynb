# %%
import numpy as np
import pandas as pd

# %%
data=pd.read_csv('/kaggle/input/new-york-housing-market/NY-House-Dataset.csv')

# %%
data.head()
# Out:
#                                          BROKERTITLE                TYPE  \
# 0        Brokered by Douglas Elliman  -111 Fifth Ave      Condo for sale
# 1                                Brokered by Serhant      Condo for sale
# 2                             Brokered by Sowae Corp      House for sale
# 3                                Brokered by COMPASS      Condo for sale
# 4  Brokered by Sotheby's International Realty - E...  Townhouse for sale
#
#        PRICE  BEDS       BATH  PROPERTYSQFT  \
# 0     315000     2   2.000000        1400.0
# 1  195000000     7  10.000000       17545.0
# 2     260000     4   2.000000        2015.0
# 3      69000     3   1.000000         445.0
# 4   55000000     7   2.373861       14175.0
#
#                                              ADDRESS                    STATE  \
# 0                               2 E 55th St Unit 803       New York, NY 10022
# 1  Central Park Tower Penthouse-217 W 57th New Yo...       New York, NY 10019
# ...

# %%
data=data.drop(['BROKERTITLE','ADDRESS','MAIN_ADDRESS','ADMINISTRATIVE_AREA_LEVEL_2','LONG_NAME','FORMATTED_ADDRESS','LATITUDE','LONGITUDE'],axis=1)

# %%
data.head()
# Out:
#                  TYPE      PRICE  BEDS       BATH  PROPERTYSQFT  \
# 0      Condo for sale     315000     2   2.000000        1400.0
# 1      Condo for sale  195000000     7  10.000000       17545.0
# 2      House for sale     260000     4   2.000000        2015.0
# 3      Condo for sale      69000     3   1.000000         445.0
# 4  Townhouse for sale   55000000     7   2.373861       14175.0
#
#                      STATE  LOCALITY      SUBLOCALITY       STREET_NAME
# 0       New York, NY 10022  New York        Manhattan  East 55th Street
# 1       New York, NY 10019  New York  New York County          New York
# 2  Staten Island, NY 10312  New York  Richmond County     Staten Island
# 3      Manhattan, NY 10022  New York  New York County          New York
# 4       New York, NY 10065  New York  New York County          New York

# %%
len(data)
# Out:
# 4801

# %%
len(data['TYPE'].value_counts())
# Out:
# 13

# %%
len(data['LOCALITY'].value_counts())
# Out:
# 11

# %%
len(data['SUBLOCALITY'].value_counts())
# Out:
# 21

# %%
len(data['STREET_NAME'].value_counts())
# Out:
# 174

# %%
data.isna().sum()
# Out:
# TYPE            0
# PRICE           0
# BEDS            0
# BATH            0
# PROPERTYSQFT    0
# STATE           0
# LOCALITY        0
# SUBLOCALITY     0
# STREET_NAME     0
# dtype: int64

# %%
data.duplicated().sum()
# Out:
# 240

# %%
data=data.drop_duplicates()

# %%
data.duplicated().sum()
# Out:
# 0

# %%
from sklearn.preprocessing import LabelEncoder,StandardScaler

# %%
TypeLE=LabelEncoder()
data['TYPE']=TypeLE.fit_transform(data['TYPE'])

# %%
TypeLE.classes_
# Out:
# array(['Co-op for sale', 'Coming Soon', 'Condo for sale',
#        'Condop for sale', 'Contingent', 'For sale', 'Foreclosure',
#        'House for sale', 'Land for sale', 'Mobile house for sale',
#        'Multi-family home for sale', 'Pending', 'Townhouse for sale'],
#       dtype=object)

# %%
data
# Out:
#       TYPE      PRICE  BEDS       BATH  PROPERTYSQFT                    STATE  \
# 0        2     315000     2   2.000000   1400.000000       New York, NY 10022
# 1        2  195000000     7  10.000000  17545.000000       New York, NY 10019
# 2        7     260000     4   2.000000   2015.000000  Staten Island, NY 10312
# 3        2      69000     3   1.000000    445.000000      Manhattan, NY 10022
# 4       12   55000000     7   2.373861  14175.000000       New York, NY 10065
# ...    ...        ...   ...        ...           ...                      ...
# 4796     0     599000     1   1.000000   2184.207862      Manhattan, NY 10075
# 4797     0     245000     1   1.000000   2184.207862      Rego Park, NY 11374
# 4798     0    1275000     1   1.000000   2184.207862       New York, NY 10011
# 4799     2     598125     2   1.000000    655.000000       Elmhurst, NY 11373
# 4800     0     349000     1   1.000000    750.000000       Brooklyn, NY 11224
#
# ...

# %%
LocalityLE=LabelEncoder()
data['LOCALITY']=LocalityLE.fit_transform(data['LOCALITY'])

# %%
LocalityLE.classes_
# Out:
# array(['Bronx County', 'Brooklyn', 'Flatbush', 'Kings County', 'New York',
#        'New York County', 'Queens', 'Queens County', 'Richmond County',
#        'The Bronx', 'United States'], dtype=object)

# %%
subLocalityLE=LabelEncoder()
data['SUBLOCALITY']=subLocalityLE.fit_transform(data['SUBLOCALITY'])

# %%
streetLE=LabelEncoder()
data['STREET_NAME']=streetLE.fit_transform(data['STREET_NAME'])

# %%
stateLE=LabelEncoder()
data['STATE']=stateLE.fit_transform(data['STATE'])

# %%
data.head()
# Out:
#    TYPE      PRICE  BEDS       BATH  PROPERTYSQFT  STATE  LOCALITY  \
# 0     2     315000     2   2.000000        1400.0    207         4
# 1     2  195000000     7  10.000000       17545.0    205         4
# 2     7     260000     4   2.000000        2015.0    301         4
# 3     2      69000     3   1.000000         445.0    161         4
# 4    12   55000000     7   2.373861       14175.0    227         4
#
#    SUBLOCALITY  STREET_NAME
# 0           10           56
# 1           12          117
# 2           16          153
# 3           12          117
# 4           12          117

# %%
x=data.drop(['PRICE'],axis=1)
y=data['PRICE']

# %%
ss=StandardScaler()
x_standarised=ss.fit_transform(x)

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
x_train,x_test,y_train,y_test=train_test_split(x_standarised,y,test_size=0.2)

# %%
lr=LinearRegression()

# %%
lr.fit(x_test,y_test)
# Out:
# LinearRegression()

# %%
lr.score(x_test,y_test)
# Out:
# 0.13986868124698204

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
rfr=RandomForestRegressor()

# %%
rfr.fit(x_train,y_train)
# Out:
# RandomForestRegressor()

# %%
rfr.score(x_test,y_test)
# Out:
# 0.4957144515930475
